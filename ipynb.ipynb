# %% [markdown]
# **1. Determine the types of the below-given variables:
# - Age
# - Salary
# - Income
# - Customer type
# - Stock price
#
# Age: discrete
#
# Salary: discrete
#
# income: continuous
#
# Customer tyrpe: categorical
#
# Stock price: discrete

# %%
**2. Using the `movie` data, we have studied in this lesson. Complete the following tasks:
    * Select a variable from the `movie` dataset and discuss the variable type of this variable
    * Categorize a variable of your choice and assign a name to it
    * Count the number of rows for each category

# %%
import pandas as pd
import numpy as np
movie = pd.read_csv("https://djl-lms-assets.s3.eu-central-1.amazonaws.com/datasets/movie.csv")
movie.columns
movie_imdb=movie["imdb_score"]
#display(movie_imdb)
movie_imdb.describe()
movie_imdb.head
def make_discrete(imdb_score):
    if imdb_score >= 7.0:
        return 1
    elif (imdb_score < 7) and (imdb_score < 5):
        return 2
    else:
        return 3
movie['imdb_group'] = movie['imdb_score'].apply(make_discrete)
display(movie.head())
movie.groupby("imdb_group")["imdb_score"].count()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
# 2  English      UK           PG-13  245000000.0     2015.0
# 3  English     USA           PG-13  250000000.0     2012.0
# 4      NaN     NaN             NaN          NaN        NaN
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78                 33000
# 1                  5000.0        7.1         2.35                     0
# 2                   393.0        6.8         2.35                 85000
# 3                 23000.0        8.5         2.35                164000
# 4                    12.0        7.1          NaN                     0
#
#   imdb_group
# 0          1
# 1          1
# 2          3
# 3          1
# 4          1
#
# [5 rows x 29 columns]
# imdb_group
# 1    1778
# 2     482
# 3    2783
# Name: imdb_score, dtype: int64

# %% [markdown]
# **3. Is it possible to convert categorical variable into numerical one? If so, how can you make that?
#
# Yes, we could use get.dummies() code

# %% [markdown]
# **4. While continuous data is generally preferred over discrete data, please indicate circumstances where discrete is the preferred data type although continuous data is available for the same characteristic.
#
# When finite number of values is possible and the values cannot be subdivided meaningfully.
# When there are countable values between any two values.
# Example: the number of computers in each department in company.

# %% [markdown]
# **5. While continuous data is measured and attribute data is counted, there is sometimes confusion if some specific dataset should be considered continuous or attribute. Provide some examples of confusing datasets and your inference.
#
# Continuous data is measurable, attribute data is counted data. The two data are different each others. On the other hands, some cases we may confuse about the data type. For example, when we withdraw money from atm it comes like 100,200,500 liras but if we see our bank balance in our records online then we can see the numbers like 200.35 liras, so it is continuous data because it has several infinite values so it is continuous data.
