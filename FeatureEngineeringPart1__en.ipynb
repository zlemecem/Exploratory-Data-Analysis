# %% [markdown]
# # <font color=blue>Assignments for "Feature Engineering - Part 1"</font>

# %% [markdown]
# In this assignment, you will continue to study the `Students Performance` ([dataset](https://www.kaggle.com/spscientist/students-performance-in-exams/home)). In this dataset, there is a lot of data on an annual basis. You can reach the explanations of this data from Kaggle again.
#
# To complete this assignment, submit the Github link of the Jupyter notebook file containing solutions to the questions below. You can talk to your mentor on your head or ask Slack at office time.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from scipy.stats.mstats import winsorize
import warnings
from sklearn.preprocessing import normalize


warnings.filterwarnings('ignore')
sns.set(style="whitegrid")
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

# %%
std = pd.read_csv("StudentsPerformance.csv")
std.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %% [markdown]
# **(1)** Are the exam scores (math, reading, writing) normally distributed? If not, what can we do to have a normal distribution?

# %%
std.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# **There is no skewed distribution for all scores.**

# %%
plt.figure(figsize=(25,8))
plt.subplot(1,3,1)
sns.distplot(std["math score"].dropna(), color="darkred")
plt.subplot(1,3,2)
sns.distplot(std["reading score"].dropna())
plt.subplot(1,3,3)
sns.distplot(std["writing score"].dropna(), color="green")
plt.show()

# %% [markdown]
# Math score looks like normal distribution. Others is small different from normal distribution. Such as the square root, inverse, or log of the variable may be implemented for the two scores.

# %% [markdown]
# **(2)** We want to keep the three exam results in one variable, as the target variable. To do this, define a new variable containing the average of the three exams. Test whether the average of this new variable is normally distributed. If it does not have a normal distribution, try to make it normally distributed by transforming and test the result of the transformation.

# %%
average=(std["math score"]+std["reading score"]+std["writing score"])/3
std["average"]=average

# %%
sns.distplot(std["average"].dropna(), color="green", bins=100)
plt.show()

# %% [markdown]
# **Seems like normal distribution but left of graph is a little different.**

# %%
std.describe()
# Out:
#        math score  reading score  writing score      average
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000    67.770667
# std      15.16308      14.600192      15.195657    14.257326
# min       0.00000      17.000000      10.000000     9.000000
# 25%      57.00000      59.000000      57.750000    58.333333
# 50%      66.00000      70.000000      69.000000    68.333333
# 75%      77.00000      79.000000      79.000000    77.666667
# max     100.00000     100.000000     100.000000   100.000000

# %%
from scipy.stats import zscore
z_scores = zscore(std["average"].dropna())
for threshold in range(1,4):
    print("Threshold value: {}".format(threshold))
    print("Number of Outliers: {}".format(len((np.where(z_scores > threshold)[0]))))
    print('------')
# Out:
# Threshold value: 1
# Number of Outliers: 165
# ------
# Threshold value: 2
# Number of Outliers: 19
# ------
# Threshold value: 3
# Number of Outliers: 0
# ------

# %%
log_ave= winsorize(np.array(np.log(std.average.dropna())), (0.10, 0.10))
plt.boxplot(log_ave)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f07f6852890>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f07f6855890>,
#   <matplotlib.lines.Line2D at 0x7f07f6855dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f07f68348d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f07f6834390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f07f6852dd0>,
#   <matplotlib.lines.Line2D at 0x7f07f6855350>]}

# %%
from scipy.stats import ttest_ind
ttest_value=stats.ttest_1samp(log_ave,70)
print(ttest_value)
# Out:
# Ttest_1sampResult(statistic=-11670.737209789411, pvalue=0.0)

# %% [markdown]
# After a log method applied, there is low p value.

# %%
std
# Out:
#      gender race/ethnicity  ... writing score    average
# 0    female        group B  ...            74  72.666667
# 1    female        group C  ...            88  82.333333
# 2    female        group B  ...            93  92.666667
# 3      male        group A  ...            44  49.333333
# 4      male        group C  ...            75  76.333333
# ..      ...            ...  ...           ...        ...
# 995  female        group E  ...            95  94.000000
# 996    male        group C  ...            55  57.333333
# 997  female        group C  ...            65  65.000000
# 998  female        group D  ...            77  74.333333
# 999  female        group D  ...            86  83.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# **(3)** Which variables seem to be related to the target variable we created in the previous question? If our goal was to explain the factors that determine the success of the exam, which variables should we keep in our data set?

# %%
std= pd.concat([std, pd.get_dummies(std["gender"])], axis=1)
std= pd.concat([std, pd.get_dummies(std["lunch"])], axis=1)
std= pd.concat([std, pd.get_dummies(std["race/ethnicity"])], axis=1)
std= pd.concat([std, pd.get_dummies(std["parental level of education"])], axis=1)
std= pd.concat([std, pd.get_dummies(std["test preparation course"])], axis=1)
std.drop(labels = ["lunch","gender","test preparation course","parental level of education","race/ethnicity"], axis = 1, inplace = True)

# %%
std["log_ave"]= log_ave
std
# Out:
#      math score  reading score  writing score  ...  completed  none   log_ave
# 0            72             72             74  ...          0     1  4.285883
# 1            69             90             88  ...          1     0  4.410776
# 2            90             95             93  ...          0     1  4.454347
# 3            47             57             44  ...          0     1  3.905334
# 4            76             78             75  ...          0     1  4.335110
# ..          ...            ...            ...  ...        ...   ...       ...
# 995          88             99             95  ...          1     0  4.454347
# 996          62             55             55  ...          0     1  4.048882
# 997          59             71             65  ...          1     0  4.174387
# 998          68             78             77  ...          1     0  4.308559
# 999          77             86             86  ...          0     1  4.418841
#
# [1000 rows x 22 columns]

# %%
std.corr()
# Out:
#                     math score  reading score  ...      none   log_ave
# math score            1.000000       0.817580  ... -0.177702  0.884838
# reading score         0.817580       1.000000  ... -0.241780  0.942524
# writing score         0.802642       0.954598  ... -0.312946  0.938375
# average               0.918746       0.970331  ... -0.256710  0.968791
# female               -0.167982       0.244313  ...  0.006028  0.138339
# male                  0.167982      -0.244313  ... -0.006028 -0.138339
# free/reduced         -0.350877      -0.229560  ... -0.017044 -0.278025
# standard              0.350877       0.229560  ...  0.017044  0.278025
# group A              -0.091977      -0.096274  ...  0.006315 -0.119266
# group B              -0.084250      -0.060283  ...  0.000106 -0.068322
# group C              -0.073387      -0.003074  ... -0.012522 -0.026422
# group D               0.050071       0.035177  ...  0.055956  0.059011
# group E               0.205855       0.106712  ... -0.059393  0.135825
# associate's degree    0.063228       0.064386  ... -0.012668  0.055327
# bachelor's degree     0.079664       0.096024  ... -0.024285  0.093541
# high school          -0.128725      -0.151068  ...  0.074446 -0.156302
# master's degree       0.060417       0.106452  ...  0.009933  0.092569
# some college          0.037056       0.010782  ...  0.019490  0.034664
# some high school     -0.079852      -0.071369  ... -0.070289 -0.071560
# completed             0.177702       0.241780  ... -1.000000  0.249622
# none                 -0.177702      -0.241780  ...  1.000000 -0.249622
# log_ave               0.884838       0.942524  ... -0.249622  1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(20,10))
p = sns.heatmap(std.corr(),fmt=".2f", annot=True)

plt.show()

# %% [markdown]
# **Math score, reading score, and writing scores are most related to the log_average column.**
#
# **We should keep test preparation course,lunch, goup E origin and all scores  values. Scores affect each other to explain the factors that determine the success of the exam.**

# %% [markdown]
# **(4)** Does the test preparation course have an impact on the target variable you created?

# %% [markdown]
# **Yes,low effect. There is a correlation between test preparation course and average but it is low value. (0.256710) If student has a preparation, his/her average score is higher.**
